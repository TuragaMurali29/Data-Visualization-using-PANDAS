# %% [markdown]
# <a href="https://colab.research.google.com/github/TuragaMurali29/Data-Visualization-using-PANDAS/blob/main/Create_Functions_To_Analyze_Using_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
datasatPath='/content/drive/MyDrive/matches_1930_2022.csv'

# %%
df=pd.read_csv(datasatPath)

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
# ...

# %%
import random

# %%
age=[]
weight=[]
height=[]

# %%
df.shape
# Out:
# (964, 44)

# %%
[age.append(random.randint(18,40))for _ in range(964)]
print(f'Age is now having {len(age)}')
# Out:
# Age is now having 964

# %%
age
# Out:
# [19,
#  37,
#  26,
#  39,
#  26,
#  33,
#  30,
#  28,
#  20,
#  32,
#  20,
#  25,
#  37,
#  35,
#  24,
#  18,
#  22,
#  37,
#  25,
#  22,
#  25,
#  25,
#  29,
#  36,
#  28,
#  30,
#  24,
#  26,
#  28,
#  20,
#  29,
#  27,
#  25,
#  26,
#  36,
#  28,
#  30,
#  29,
#  34,
#  18,
#  33,
#  18,
#  20,
#  30,
#  20,
#  27,
#  20,
#  32,
#  29,
#  25,
#  31,
#  26,
#  18,
#  36,
#  24,
#  32,
#  32,
#  24,
#  31,
#  35,
#  27,
#  22,
#  37,
#  34,
#  18,
#  20,
#  19,
#  35,
#  28,
#  29,
#  31,
#  35,
#  25,
#  26,
#  40,
#  32,
#  35,
#  32,
#  29,
#  20,
#  38,
#  25,
#  22,
#  33,
#  31,
#  26,
#  35,
#  21,
#  27,
#  29,
#  23,
#  39,
#  32,
#  29,
#  35,
#  21,
#  31,
#  19,
#  19,
#  20,
#  23,
#  23,
#  39,
#  38,
#  36,
#  20,
#  19,
#  37,
#  19,
#  39,
#  27,
#  24,
#  18,
#  35,
#  40,
#  28,
#  31,
#  30,
#  25,
#  35,
#  35,
#  36,
#  34,
#  30,
#  31,
#  23,
#  21,
#  26,
#  30,
#  33,
#  33,
#  31,
#  32,
#  37,
#  34,
#  29,
#  33,
#  24,
#  32,
#  38,
#  28,
#  32,
# ...

# %%
df['YearsOfExperience']=age

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
# ...

# %%
df['ASP']=df['YearsOfExperience']-df['home_score']

# %%
df.shape
# Out:
# (964, 46)

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
# ...

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
df.plot(x='YearsOfExperience',y=['ASP','home_score'],kind='bar',color=['green','red'])
# Out:
# <Axes: xlabel='YearsOfExperience'>

# %%
df.plot(x='ASP',y=['away_score','home_score'],kind='bar',color='green')
# Out:
# <Axes: xlabel='ASP'>

# %%
#Function to get a garph
def getGraph(DataFrame,Column1,Column2):
    from matplotlib import pyplot as plt # Indent this line and subsequent lines within the function
    #
    if len(DataFrame[Column1])==len(DataFrame[Column2]):
        df.plot(x=Column1,y=Column2,kind='bar',color=['skyblue','pink'])
        print('The graph/plot is succesfully created')
    else:
        print('Please check the column size once')
getGraph(df,'home_score','away_score')
# Out:
# The graph/plot is succesfully created
